# %%
import pandas as pd

# %%
dataset = pd.DataFrame({
    'Sexo': ['H', 'M', 'M', 'M', 'M', 'H', 'H', 'H', 'M', 'M'],
    'Idade': [53, 72, 54, 27, 30, 40, 58, 32, 44, 51]
})

# %%
dataset.Idade.mean()
# Out:
# 46.1

# %%
dataset.groupby(['Sexo'])['Idade'].mean()
# Out:
# Sexo
# H    45.750000
# M    46.333333
# Name: Idade, dtype: float64

# %%
df = pd.DataFrame(data = {'Fulano': [8, 10, 4, 8, 6, 10, 8],
                          'Sicrano': [7.5, 8, 7, 8, 8, 8.5, 7]}, 
                  index = ['Matemática', 
                           'Português', 
                           'Inglês', 
                           'Geografia', 
                           'História', 
                           'Física', 
                           'Química'])
df.rename_axis('Matérias', axis = 'columns', inplace = True)
df
# Out:
# Matérias    Fulano  Sicrano
# Matemática       8      7.5
# Português       10      8.0
# Inglês           4      7.0
# Geografia        8      8.0
# História         6      8.0
# Física          10      8.5
# Química          8      7.0

# %%
df.describe()
# Out:
# Matérias     Fulano   Sicrano
# count      7.000000  7.000000
# mean       7.714286  7.714286
# std        2.138090  0.566947
# min        4.000000  7.000000
# 25%        7.000000  7.250000
# 50%        8.000000  8.000000
# 75%        9.000000  8.000000
# max       10.000000  8.500000

# %%
dataset = pd.DataFrame({
    'Sexo': ['H', 'M', 'M', 'M', 'M', 'H', 'H', 'H', 'M', 'M'],
    'Idade': [53, 72, 54, 27, 30, 40, 58, 32, 44, 51]
})
dataset
# Out:
#   Sexo  Idade
# 0    H     53
# 1    M     72
# 2    M     54
# 3    M     27
# 4    M     30
# 5    H     40
# 6    H     58
# 7    H     32
# 8    M     44
# 9    M     51

# %%
dataset.std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of   Sexo  Idade
# 0    H     53
# 1    M     72
# 2    M     54
# 3    M     27
# 4    M     30
# 5    H     40
# 6    H     58
# 7    H     32
# 8    M     44
# 9    M     51>

# %%
from scipy.special import comb

# %%
combinacoes = comb(25, 20)
combinacoes
# Out:
# 53130.0

# %%
probabilidade = 1/combinacoes
print('% 0.15f' % probabilidade)
# Out:
#  0.000018821757952

# %% [markdown]
# ###### Uma moeda, perfeitamente equilibrada, é lançada para o alto quatro vezes. Utilizando a distribuição binomial, obtenha a probabilidade de a moeda cair com a face coroa voltada para cima duas vezes.

# %%
# Numero de eventos
n = 4
n
# Out:
# 4

# %%
numero_de_faces = 2
p = 1/numero_de_faces
p
# Out:
# 0.5

# %%
q = 1 - p
q
# Out:
# 0.5

# %%
k = 2
k
# Out:
# 2

# %%
from scipy.stats import binom

# %%
probabilidade = binom.pmf(k, n, p)
print('%0.8f' % probabilidade)
# Out:
# 0.37500000

# %% [markdown]
# ###### Um dado, perfeitamente equilibrado, é lançado para o alto dez vezes. Utilizando a distribuição binomial, obtenha a probabilidade de o dado cair com o número cinco voltado para cima pelo menos três vezes.

# %%
# Numero de eventos
n = 10
n
# Out:
# 10

# %%
#Probabilidade sucesso
numero_de_faces = 6
p = 1/numero_de_faces
p
# Out:
# 0.16666666666666666

# %%
# Probabilidade fracasso
q = 1 - p
q
# Out:
# 0.8333333333333334

# %%
# Eventos que deseja obter sucesso
k = 3
k
# Out:
# 3

# %%
# Importando biblioteca
from scipy.stats import binom

# %%
# Calculando probabilidade de acertar pelo menos 3 vezes
binom.pmf([3, 4, 5, 6, 7, 8, 9, 10], n, p).sum()
# Out:
# 0.2247732021287407

# %% [markdown]
# #### Suponha que a probabilidade de um casal ter filhos com olhos azuis seja de 22%. Em 50 famílias, com 3 crianças cada uma, quantas podemos esperar que tenham dois filhos com olhos azuis?

# %%
p = 0.22
p
# Out:
# 0.22

# %%
n = 3
n
# Out:
# 3

# %%
k = 2
k
# Out:
# 2

# %%
probabilidade = binom.pmf(k, n, p)
print('%0.8f' % probabilidade)
# Out:
# 0.11325600

# %%
filhos_olhos_azuis = 50*probabilidade
filhos_olhos_azuis
# Out:
# 5.662799999999999

# %% [markdown]
# ####O número médio de clientes que entram em uma padaria por hora é igual a 20. Obtenha a probabilidade de, na próxima hora, entrarem exatamente 25 clientes.

# %%
media = 20
media
# Out:
# 20

# %%
k = 25
k
# Out:
# 25

# %%
from scipy.stats import poisson
probabilidade = poisson.pmf(k, media)
print('%0.8f'% probabilidade)
# Out:
# 0.04458765

# %% [markdown]
# #### A aplicação de uma prova de estatística em um concurso apresentou um conjunto de notas normalmente distribuídas. Verificou-se que o conjunto de notas tinha média 70 e desvio padrão de 5 pontos.
#
# Qual a probabilidade de um aluno, selecionado ao acaso, ter nota menor que 85?

# %%
media = 70
media
# Out:
# 70

# %%
desvio_padrao = 5
desvio_padrao
# Out:
# 5

# %%
z = (85 - media)/desvio_padrao
z
# Out:
# 3.0

# %%
# Solução usando tabela
probabilidade = 0.9987
probabilidade
# Out:
# 0.9987

# %%
# Solução usando scipy
from scipy.stats import norm
norm.cdf(z)
# Out:
# 0.9986501019683699

# %% [markdown]
# #### O faturamento diário de um motorista de aplicativo segue uma distribuição aproximadamente normal, com média R$ 300,00 e desvio padrão igual a R$ 50,00. Obtenha as probabilidades de que, em um dia aleatório, o motorista ganhe:
#
# 1) Entre R$ 250,00 e R$ 350,00
#
# 2) Entre R$ 400,00 e R$ 500,00

# %%
media = 300
media
# Out:
# 300

# %%
desvio_padrao = 50
desvio_padrao
# Out:
# 50

# %%
z = (300 - media)/desvio_padrao
z
# Out:
# 0.0

# %%
z = (250 - media)/desvio_padrao
z
# Out:
# -1.0

# %%
probabilidade = (0.5 - 0.1587)*2
probabilidade
# Out:
# 0.6826

# %%
z = (500 - media)/desvio_padrao
z
# Out:
# 4.0

# %%
z = (400 - media)/desvio_padrao
z
# Out:
# 2.0

# %%
probabilidade = (1- 0.9772)
probabilidade
# Out:
# 0.022800000000000042

# %% [markdown]
# ##### O Inmetro verificou que as lâmpadas incandescentes da fabricante XPTO apresentam uma vida útil normalmente distribuída, com média igual a 720 dias e desvio padrão igual a 30 dias. Calcule a probabilidade de uma lâmpada, escolhida ao acaso, durar:
#
# 1) Entre 650 e 750 dias
#
# 2) Mais que 800 dias
#
# 3) Menos que 700 dias

# %%
media = 720
media
# Out:
# 720

# %%
desvio_padrao = 30
desvio_padrao
# Out:
# 30

# %%
z = (750 - media)/desvio_padrao
z
# Out:
# 1.0

# %%
z = (650 - media)/desvio_padrao
z
# Out:
# -2.3333333333333335

# %%
probabilidade = (0.8413 - (1 - 0.9901))*100
probabilidade
# Out:
# 83.14

# %%
z = (800 - media)/desvio_padrao
z
# Out:
# 2.6666666666666665

# %%
probabilidade = (1 - 0.9961)*100
probabilidade
# Out:
# 0.39000000000000146

# %%
z = (700 - media)/desvio_padrao
z
# Out:
# -0.6666666666666666

# %%
probabilidade = (1- 0.7422)*100
probabilidade
# Out:
# 25.78

# %% [markdown]
# ##### Utilizando a tabela padronizada, ou o ferramental disponibilizado pelo Python, encontre a área sob a curva normal para os valores de Z abaixo:
#
# 1) Z < 1,96
#
# 2) Z > 2,15
#
# 3) Z < -0,78
#
# 4) Z > 0,59

# %%
z = 0.9750
z
# Out:
# 0.975

# %%
z = 1 - 0.9842
z
# Out:
# 0.015800000000000036

# %%
z = 1 - 0.7823
z
# Out:
# 0.2177

# %%
z = 1 - 0.7224
z
# Out:
# 0.27759999999999996

# %% [markdown]
# ###### Para estimar o valor médio gasto por cada cliente de uma grande rede de fast-food, foi selecionada uma amostra de 50 clientes.
#
# Assumindo que o valor do desvio padrão da população seja de R$ 6,00 e que esta população se distribui normalmente, obtenha a margem de erro desta estimativa para um nível de confiança de 95%.

# %%
confianca = 0.95
confianca
# Out:
# 0.95

# %%
significancia = -confianca + 1
significancia
# Out:
# 0.050000000000000044

# %%
desvio_padrao = 6
desvio_padrao
# Out:
# 6

# %%
n = 50
n
# Out:
# 50

# %%
import numpy as np

# %%
raiz_de_n = np.sqrt(n)
raiz_de_n
# Out:
# 7.0710678118654755

# %%
sigma = desvio_padrao/raiz_de_n
sigma
# Out:
# 0.848528137423857

# %%
z = 1.96
z
# Out:
# 1.96

# %%
e = z*sigma
e
# Out:
# 1.6631151493507597

# %% [markdown]
# ##### Uma amostra aleatória simples de 1976 itens de uma população normalmente distribuída, com desvio padrão populacional igual a 11, resultou em uma média amostral de 28.
#
# Qual o intervalo de confiança de 90% para a média populacional?

# %%
confianca = 0.90
confianca
# Out:
# 0.9

# %%
significancia = -confianca + 1
significancia
# Out:
# 0.09999999999999998

# %%
desvio_padrao = 11
desvio_padrao
# Out:
# 11

# %%
n = 1976
n
# Out:
# 1976

# %%
raiz_de_n = np.sqrt(n)
raiz_de_n
# Out:
# 44.45222154178574

# %%
sigma = desvio_padrao/raiz_de_n
sigma
# Out:
# 0.24745669886621613

# %%
z = 1.645
z
# Out:
# 1.645

# %%
e = z*sigma
e
# Out:
# 0.40706626963492554

# %%
media_amostra = 28
media_amostra
# Out:
# 28

# %%
intervalo = (media_amostra - e, media_amostra + e)
intervalo
# Out:
# (27.592933730365075, 28.407066269634925)

# %% [markdown]
# ###### O valor do gasto médio dos clientes de uma loja de conveniência é de R$ 45,50. Assumindo que o desvio padrão dos gastos é igual a R$ 15,00, qual deve ser o tamanho da amostra para estimarmos a média populacional com um nível de significância de 10%?
#
# Considere que o erro máximo aceitável seja de 10%.

# %%
# Calculando erro e significancia com base da porcentagem levando em conta a média
(45.5*0.1)/1
# Out:
# 4.55

# %%
significancia = 4.55
significancia
# Out:
# 4.55

# %%
confianca = 1 - significancia
confianca
# Out:
# -3.55

# %%
z = 1.645
z
# Out:
# 1.645

# %%
sigma = 15
sigma
# Out:
# 15

# %%
e = 4.55
e
# Out:
# 4.55

# %%
n = (z*(sigma/e))**2
n
# Out:
# 29.40976331360947

# %% [markdown]
# ###### Um fabricante de farinha verificou que, em uma amostra aleatória formada por 200 sacos de 25 kg de um lote formado por 2.000 sacos, apresentou um desvio padrão amostral do peso igual a 480 g.
#
# Considerando um erro máximo associado à média populacional igual a 0,3 kg e um nível de confiança igual a 95%, qual tamanho de amostra deveria ser selecionado para obtermos uma estimativa confiável do parâmetro populacional?

# %%
N = 2000
N
# Out:
# 2000

# %%
z = norm.ppf((0.5 + (0.95/2)))
z
# Out:
# 1.959963984540054

# %%
s = 480
s
# Out:
# 480

# %%
e = 300
e
# Out:
# 300

# %%
n = ((z**2)*(s**2)*(N))/(((z**2)*(s**2))+((e**2)*(N - 1)))
int(n.round())
# Out:
# 10

# %%
import pandas as pd
import numpy as np
from scipy.stats import binom
from scipy.stats import norm

# %%
dados = pd.read_csv('dados.csv')

# %%
dataset = dados.Renda.sample(n = 200, random_state = 101)

# %%
dataset.mean()
# Out:
# 1964.205

# %%
dataset.std()
# Out:
# 3139.8855167452157

# %%
media_amostra = dataset.mean()
media_amostra
# Out:
# 1964.205

# %%
desvio_padrao_amostra = dataset.std()
desvio_padrao_amostra
# Out:
# 3139.8855167452157

# %%
recursos = 150000
custo_entrevista = 100

# %%
e = 0.10 * media_amostra
print('A margem de erro é de R$ %0.2f para mais ou para menos' % (e))
# Out:
# A margem de erro é de R$ 196.42 para mais ou para menos

# %%
z = norm.ppf(.95)
z
# Out:
# 1.6448536269514722

# %%
n_confianca_90 = (z * (desvio_padrao_amostra / e)) ** 2
n_confianca_90 = int(n_confianca_90.round())
print('Para um nível de confiança de 90%% devemos selecionar uma amostra de %s elementos.' % n_confianca_90)
